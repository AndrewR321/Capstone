# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cip = pd.read_csv("../data/Commerical_Insurance_Premiums.csv")
cip.head()
# Out:
#    Year Single Coverage Family Coverage
# 0  1999          $2,196          $5,791
# 1  2000         $2,471*         $6,438*
# 2  2001         $2,689*         $7,061*
# 3  2002         $3,083*         $8,003*
# 4  2003         $3,383*         $9,068*

# %%
cip.dtypes
# Out:
# Year                int64
# Single Coverage    object
# Family Coverage    object
# dtype: object

# %%
cip['Single Coverage'] = cip['Single Coverage'].str.rstrip("*")
cip['Family Coverage'] = cip['Family Coverage'].str.rstrip("*")
cip
# Out:
#     Year Single Coverage Family Coverage
# 0   1999          $2,196          $5,791
# 1   2000          $2,471          $6,438
# 2   2001          $2,689          $7,061
# 3   2002          $3,083          $8,003
# 4   2003          $3,383          $9,068
# 5   2004          $3,695          $9,950
# 6   2005          $4,024         $10,880
# 7   2006          $4,242         $11,480
# 8   2007          $4,479         $12,106
# 9   2008          $4,704         $12,680
# 10  2009          $4,824         $13,375
# 11  2010          $5,049         $13,770
# 12  2011          $5,429         $15,073
# 13  2012          $5,615         $15,745
# 14  2013          $5,884         $16,351
# 15  2014          $6,025         $16,834
# 16  2015          $6,251         $17,545
# 17  2016          $6,435         $18,142
# 18  2017          $6,690         $18,764
# 19  2018          $6,896         $19,616
# 20  2019          $7,188         $20,576
# 21  2020          $7,470         $21,342
# 22  2021          $7,739         $22,221
# 23  2022          $7,911         $22,463
# 24  2023          $8,435         $23,968

# %%
cip['Single Coverage'] = cip['Single Coverage'].str.lstrip("$")
cip['Family Coverage'] = cip['Family Coverage'].str.lstrip("$")
cip
# Out:
#     Year Single Coverage Family Coverage
# 0   1999           2,196           5,791
# 1   2000           2,471           6,438
# 2   2001           2,689           7,061
# 3   2002           3,083           8,003
# 4   2003           3,383           9,068
# 5   2004           3,695           9,950
# 6   2005           4,024          10,880
# 7   2006           4,242          11,480
# 8   2007           4,479          12,106
# 9   2008           4,704          12,680
# 10  2009           4,824          13,375
# 11  2010           5,049          13,770
# 12  2011           5,429          15,073
# 13  2012           5,615          15,745
# 14  2013           5,884          16,351
# 15  2014           6,025          16,834
# 16  2015           6,251          17,545
# 17  2016           6,435          18,142
# 18  2017           6,690          18,764
# 19  2018           6,896          19,616
# 20  2019           7,188          20,576
# 21  2020           7,470          21,342
# 22  2021           7,739          22,221
# 23  2022           7,911          22,463
# 24  2023           8,435          23,968

# %%
cip['Single Coverage'] = cip['Single Coverage'].replace(',','', regex=True).astype('int')
cip['Family Coverage'] = cip['Family Coverage'].replace(',','', regex=True).astype('int')
cip
# Out:
#     Year  Single Coverage  Family Coverage
# 0   1999             2196             5791
# 1   2000             2471             6438
# 2   2001             2689             7061
# 3   2002             3083             8003
# 4   2003             3383             9068
# 5   2004             3695             9950
# 6   2005             4024            10880
# 7   2006             4242            11480
# 8   2007             4479            12106
# 9   2008             4704            12680
# 10  2009             4824            13375
# 11  2010             5049            13770
# 12  2011             5429            15073
# 13  2012             5615            15745
# 14  2013             5884            16351
# 15  2014             6025            16834
# 16  2015             6251            17545
# 17  2016             6435            18142
# 18  2017             6690            18764
# 19  2018             6896            19616
# 20  2019             7188            20576
# 21  2020             7470            21342
# 22  2021             7739            22221
# 23  2022             7911            22463
# 24  2023             8435            23968

# %%
cip.dtypes
# Out:
# Year               int64
# Single Coverage    int32
# Family Coverage    int32
# dtype: object

# %%
sns.barplot(data=cip, x='Year', y='Single Coverage')
plt.xticks(rotation=45);

# %%
sns.barplot(data=cip, x='Year', y='Family Coverage')
plt.xticks(rotation=45);

# %%
le = pd.read_csv("../data/US_life_expectancy_macro.csv")
le.head()
# Out:
#          date  avg_life_expectancy  yoy_%_change  year
# 0  12/31/1950                68.14           NaN  1950
# 1  12/31/1951                68.33          0.28  1951
# 2  12/31/1952                68.52          0.28  1952
# 3  12/31/1953                68.71          0.28  1953
# 4  12/31/1954                68.90          0.28  1954

# %%
le = (
    le
        [['year', 'avg_life_expectancy', 'yoy_%_change']]
)
le
# Out:
#      year  avg_life_expectancy  yoy_%_change
# 0    1950               68.140           NaN
# 1    1951               68.330          0.28
# 2    1952               68.520          0.28
# 3    1953               68.710          0.28
# 4    1954               68.900          0.28
# ..    ...                  ...           ...
# 146  2096               88.376          0.12
# 147  2097               88.478          0.12
# 148  2098               88.580          0.12
# 149  2099               88.682          0.12
# 150  2100               88.784          0.12
#
# [151 rows x 3 columns]

# %%
le= le[le['year']>1998]

# %%
le= le[le['year']<2024]

# %%
le.head(50)
# Out:
#     year  avg_life_expectancy  yoy_%_change
# 49  1999               76.612          0.19
# 50  2000               76.754          0.19
# 51  2001               76.896          0.19
# 52  2002               77.038          0.18
# 53  2003               77.180          0.18
# 54  2004               77.382          0.26
# 55  2005               77.584          0.26
# 56  2006               77.786          0.26
# 57  2007               77.988          0.26
# 58  2008               78.190          0.26
# 59  2009               78.340          0.19
# 60  2010               78.490          0.19
# 61  2011               78.640          0.19
# 62  2012               78.790          0.19
# 63  2013               78.940          0.19
# 64  2014               78.914         -0.03
# 65  2015               78.888         -0.03
# 66  2016               78.862         -0.03
# 67  2017               78.836         -0.03
# 68  2018               78.810         -0.03
# 69  2019               78.870          0.08
# 70  2020               78.930          0.08
# 71  2021               78.990          0.08
# 72  2022               79.050          0.08
# 73  2023               79.110          0.08

# %%
sns.lineplot(data=le, x='year', y='avg_life_expectancy', markers='o')
plt.xticks(rotation=45);
