# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pop = pd.read_csv("./data/HISTPOP_OECD_Stat.csv")
pop.head()
# Out:
#   LOCATION    Country SEX    Sex    AGE    Age  TIME  Time      Value  \
# 0      AUS  Australia   W  Women  TOTAL  Total  1960  1960  5082700.0
# 1      AUS  Australia   W  Women  TOTAL  Total  1961  1961  5195900.0
# 2      AUS  Australia   W  Women  TOTAL  Total  1962  1962  5301300.0
# 3      AUS  Australia   W  Women  TOTAL  Total  1963  1963  5407000.0
# 4      AUS  Australia   W  Women  TOTAL  Total  1964  1964  5516400.0
#
#    Flag Codes  Flags
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
pop.dtypes
# Out:
# LOCATION       object
# Country        object
# SEX            object
# Sex            object
# AGE            object
# Age            object
# TIME            int64
# Time            int64
# Value         float64
# Flag Codes    float64
# Flags         float64
# dtype: object

# %%
USpop = pop.loc[pop['Country'] == 'United States']

# %%
USpop = USpop.loc[pop['SEX'] == 'T'].reset_index()
USpop
# Out:
#     index LOCATION        Country SEX    Sex    AGE    Age  TIME  Time  \
# 0    5607      USA  United States   T  Total  TOTAL  Total  1960  1960
# 1    5608      USA  United States   T  Total  TOTAL  Total  1961  1961
# 2    5609      USA  United States   T  Total  TOTAL  Total  1962  1962
# 3    5610      USA  United States   T  Total  TOTAL  Total  1963  1963
# 4    5611      USA  United States   T  Total  TOTAL  Total  1964  1964
# ..    ...      ...            ...  ..    ...    ...    ...   ...   ...
# 58   5665      USA  United States   T  Total  TOTAL  Total  2018  2018
# 59   5666      USA  United States   T  Total  TOTAL  Total  2019  2019
# 60   5667      USA  United States   T  Total  TOTAL  Total  2020  2020
# 61   5668      USA  United States   T  Total  TOTAL  Total  2021  2021
# 62   5669      USA  United States   T  Total  TOTAL  Total  2022  2022
#
#           Value  Flag Codes  Flags
# 0   180671158.0         NaN    NaN
# 1   183691481.0         NaN    NaN
# ...
